# %% [markdown]
# ## Redes de Carreteras con Python

# %% [markdown]
# # Obtención de datos de la red de carreteras OpenStretMap (OSM)
# import osmnx as ox

# %%
admin = ox.geocode_to_gdf('Asuncion')
admin_poly = admin.geometry.values[0]
admin_poly
# Out:
# <POLYGON ((-57.674 -25.315, -57.674 -25.317, -57.671 -25.32, -57.67 -25.323,...>

# %%
G = ox.graph_from_polygon(admin_poly)

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (20699, 55443)

# %%
nodes,edges = ox.graph_to_gdfs(G)

# %%
import matplotlib.pyplot as plt 
plt.style.use('dark_background')

# %%
f, ax = plt.subplots(1,1,figsize = (10,10))

edges.plot(ax=ax, edgecolor = 'orange', linewidth = 0.3)
ax.axis('off')
# Out:
# (-57.67786239, -57.51961661, -25.37241016, -25.21747164)
